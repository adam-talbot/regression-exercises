# %%
# standard imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Custom module imports
import wrangle as w
import explore as e

# %%
train, validate, test = w.wrangle_zillow()

# %%
train.head()
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 1029630           2          2.0                          2061
# 1168014           4          2.0                          1902
# 488819            3          2.0                          2086
# 243088            4          2.0                          2096
# 1508871           3          4.0                          2876
#
#          taxvaluedollarcnt  yearbuilt  taxamount   fips
# 1029630           312381.0       1956    4080.30  06037
# 1168014           420728.0       1971    4843.26  06037
# 488819            143683.0       1955    2194.57  06037
# 243088            731905.0       1959    8656.04  06037
# 1508871           780947.0       1959    9569.81  06037

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1433959 entries, 1029630 to 362745
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   bedroomcnt                    1433959 non-null  int64
#  1   bathroomcnt                   1433959 non-null  float64
#  2   calculatedfinishedsquarefeet  1433959 non-null  int64
#  3   taxvaluedollarcnt             1433959 non-null  float64
#  4   yearbuilt                     1433959 non-null  int64
#  5   taxamount                     1433959 non-null  float64
#  6   fips                          1433959 non-null  string
# dtypes: float64(3), int64(3), string(1)
# memory usage: 87.5 MB

# %%
train.describe()
# Out:
#          bedroomcnt   bathroomcnt  calculatedfinishedsquarefeet  \
# count  1.433959e+06  1.433959e+06                  1.433959e+06
# mean   3.219446e+00  2.060751e+00                  1.653997e+03
# std    7.775761e-01  7.004336e-01                  5.624388e+02
# min    2.000000e+00  1.000000e+00                  1.000000e+00
# 25%    3.000000e+00  2.000000e+00                  1.233000e+03
# 50%    3.000000e+00  2.000000e+00                  1.549000e+03
# 75%    4.000000e+00  2.500000e+00                  1.986000e+03
# max    5.000000e+00  4.000000e+00                  3.411000e+03
#
#        taxvaluedollarcnt     yearbuilt     taxamount
# count       1.433959e+06  1.433959e+06  1.433959e+06
# mean        3.281262e+05  1.960040e+03  4.067467e+03
# std         1.978116e+05  1.884779e+01  2.224107e+03
# min         2.200000e+01  1.915000e+03  1.872000e+01
# 25%         1.746960e+05  1.950000e+03  2.379510e+03
# 50%         2.976180e+05  1.957000e+03  3.751360e+03
# ...

# %%
train_sample = train.sample(n=5000, random_state=527)

# %%
e.plot_variable_pairs(train_sample)

# %%
def plot_variable_pairs_cat_hue(df):
    cat_cols = df.select_dtypes('string').columns.tolist()
    for cat in cat_cols:
        sns.pairplot(data=df, hue=cat, corner=True);

# %%
plot_variable_pairs_cat_hue(train_sample)

# %%
cat_cols = train.select_dtypes('string').columns.tolist()

# %%
num_cols = train.select_dtypes('number').columns.tolist()

# %%
e.plot_categorical_and_continuous_vars(train_sample, cat_cols, num_cols)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# fips
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ----------------------------------------------------------------------------------------------------------
# bedroomcnt
# ----------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------
# bathroomcnt
# ----------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------
# calculatedfinishedsquarefeet
# ----------------------------------------------------------------------------------------------------------
# ...
